# %% [markdown]
# <a href="https://colab.research.google.com/github/ab-fatima05/CIS-3120/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello Again!")
# Out:
# Hello Again!

# %% [markdown]
# # Hello World Program

# %% [markdown]
# My Hello World program works
